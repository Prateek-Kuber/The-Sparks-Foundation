# %% [markdown]
# # Author -Kushal Das

# %% [markdown]
# ### Stock Market Prediction using Numerical and Textual Analysis
# - Create a hybrid model for stock price or performance prediction using numerical analysis of historical stock prices, and sentimental analysis of news headlines. The stock to analyze and predict is SENSEX (S&P BSE SENSEX)

# %% [markdown]
# # Import the Important Libraries

# %%
# !pip install pandas_datareader
# Out:
# Requirement already satisfied: pandas_datareader in f:\anaconda\lib\site-packages (0.9.0)
# Requirement already satisfied: lxml in f:\anaconda\lib\site-packages (from pandas_datareader) (4.3.2)
# Requirement already satisfied: requests>=2.19.0 in f:\anaconda\lib\site-packages (from pandas_datareader) (2.21.0)
# Requirement already satisfied: pandas>=0.23 in f:\anaconda\lib\site-packages (from pandas_datareader) (0.24.2)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in f:\anaconda\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in f:\anaconda\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in f:\anaconda\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in f:\anaconda\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2019.3.9)
# Requirement already satisfied: python-dateutil>=2.5.0 in f:\anaconda\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.8.0)
# Requirement already satisfied: pytz>=2011k in f:\anaconda\lib\site-packages (from pandas>=0.23->pandas_datareader) (2018.9)
# Requirement already satisfied: numpy>=1.12.0 in f:\anaconda\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.19.5)
# Requirement already satisfied: six>=1.5 in f:\anaconda\lib\site-packages (from python-dateutil>=2.5.0->pandas>=0.23->pandas_datareader) (1.15.0)

# %%
# Import the libraries
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')


from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

import nltk
import re
from textblob import TextBlob
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
import xgboost
import lightgbm

# %%
# For reading stock data from yahoo
from pandas_datareader.data import DataReader
# For time stamps
from datetime import datetime

# %%
# Load the first dataset
columns=['Date','Category','News']
ndf = pd.read_csv("india-news-headlines.csv",names=columns)

# %%
print('Showing part of the whole dataset:')
ndf.head(5)
# Out:
# Showing part of the whole dataset:
#            Date           Category  \
# 0  publish_date  headline_category
# 1      20010101         sports.wwe
# 2      20010102            unknown
# 3      20010102            unknown
# 4      20010102            unknown
#
#                                                 News
# 0                                      headline_text
# 1  win over cena satisfying but defeating underta...
# 2  Status quo will not be disturbed at Ayodhya; s...
# 3                Fissures in Hurriyat over Pak visit
# 4              America's unwanted heading for India?

# %%
ndf.drop(0, inplace=True)
ndf.drop('Category', axis = 1, inplace=True)
print('Showing part of the whole dataset:')
ndf.head(-5)
# Out:
# Showing part of the whole dataset:
#              Date                                               News
# 1        20010101  win over cena satisfying but defeating underta...
# 2        20010102  Status quo will not be disturbed at Ayodhya; s...
# 3        20010102                Fissures in Hurriyat over Pak visit
# 4        20010102              America's unwanted heading for India?
# 5        20010102                 For bigwigs; it is destination Goa
# 6        20010102               Extra buses to clear tourist traffic
# 7        20010102        Dilute the power of transfers; says Riberio
# 8        20010102                  Focus shifts to teaching of Hindi
# 9        20010102               IT will become compulsory in schools
# 10       20010102      Move to stop freedom fighters' pension flayed
# 11       20010102  Gilani claims he applied for passport 2 years ago
# 12       20010102                     Parivar dismisses PM's warning
# 13       20010102              India; Pak exchange lists of N-plants
# 14       20010102        Will Qureshi's return really help the govt?
# 15       20010102         PM's tacit message: Put Ram tample on hold
# 16       20010102               Text of the Prime Minister's article
# 17       20010102             NCW to focus on violence against women
# 18       20010102               BBC's reality TV will focus on AIIMS
# 19       20010102                      Jaitley firm on legal reforms
# 20       20010102              Hoshangabad farmers have enough water
# 21       20010102         BJP jumps into rail track conversion issue
# 22       20010102              America's unwanted heading for India?
# 23       20010102            State may take AP to court over Krishna
# 24       20010102                  This official has sued the briber
# 25       20010102      Park turns temple compound as residents watch
# 26       20010102       Moves afoot to evict squatters in Urban dist
# 27       20010102           Mafia calls the shots in Gandhinagar too
# 28       20010102  Status quo will not be disturbed at Ayodhya; s...
# 29       20010102                Fissures in Hurriyat over Pak visit
# 30       20010102              America's unwanted heading for India?
# ...           ...                                                ...
# 3297138  20200630                 Aurangabad returnee tests positive
# 3297139  20200630  One tola gold & 1kg silver create price ratio ...
# 3297140  20200630       Remove illegal signage or face penalty: NDMC
# 3297141  20200630      moto g 5g plus with 5000 mah battery launched
# 3297142  20200630  instagram launches tiktok rival reels in india...
# 3297143  20200630  covid 19 fresh cases breach 25000 in a day for...
# 3297144  20200630  mbose 12th result live updates meghalaya hsslc...
# 3297145  20200630  amazon app quiz july 9 2020 get answers to the...
# 3297146  20200630  watch adnan sami pays a video tribute to veter...
# 3297147  20200630  throwback when jaaved jaaferi spoke about his ...
# 3297148  20200630  ankita lokhandes beau vicky jain limits commen...
# 3297149  20200630  veteran actor jagdeeps demise jaaved jaaferi a...
# 3297150  20200630  hollywood star naya rivera missing and presume...
# 3297151  20200630  covid 19 medicine gilead starts testing for in...
# 3297152  20200630  horoscope today 10 july 2020 check astrologica...
# 3297153  20200630  sanjay dutt remembers jagdeep on his demise sa...
# 3297154  20200630  telangana intermediate second year advanced su...
# 3297155  20200630  salim khan comedy ke liye timing bohot zaroori...
# 3297156  20200630  clinical trials of coronavirus vaccine begin i...
# 3297157  20200630  india again rejects chinas claim over galwan v...
# 3297158  20200630  pm modi to inaugurate asias largest 750 mw rew...
# 3297159  20200630        what bengaluru can do to tackle covid surge
# 3297160  20200630  prabhas gets nostalgic as baahubali the beginn...
# 3297161  20200630             cbse course cut to impact jee neet too
# 3297162  20200630   karnataka may adopt keralas triple lockdown plan
# 3297163  20200630  vehicle of up stf team bringing gangster vikas...
# 3297164  20200630  sushant singh rajputs demise fans trend cbifor...
# 3297165  20200630  amitabh bachchans grandson agastya nanda prepp...
# 3297166  20200630  icse isc result 2020 when where to check class...
# 3297167  20200630  up govt imposes weekend restrictions from tonight
#
# [3297167 rows x 2 columns]

# %%
# Load the second dataset
.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3297172 entries, 1 to 3297172
# Data columns (total 2 columns):
# Date    datetime64[ns]
# News    object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 75.5+ MB

# %%
# Group the headlines for each day
ndf['News'] = ndf.groupby(['Date']).transform(lambda x : ' '.join(x)) 
ndf = ndf.drop_duplicates() 
ndf.reset_index(inplace=True,drop=True)

# %%
ndf
# Out:
#            Date                                               News
# 0    2001-01-01  win over cena satisfying but defeating underta...
# 1    2001-01-02  Status quo will not be disturbed at Ayodhya; s...
# 2    2001-01-03  Powerless north India gropes in the dark Think...
# 3    2001-01-04  The string that pulled Stephen Hawking to Indi...
# 4    2001-01-05  Light combat craft takes India into club class...
# 5    2001-01-06  Light combat craft takes India into club class...
# 6    2001-01-07  Muslim body rules out talks on Ayodhya Bajrang...
# 7    2001-01-08  Sangh Parivar; Babri panel up the ante Frontru...
# 8    2001-01-09  Financier Bharat Shah held for alleged links w...
# 9    2001-01-10  Fend for yourselves; Pande tells doctors Burea...
# 10   2001-01-11  shreyas gopal scores ton as karnataka stay on ...
# 11   2001-01-23  Sonia takes on the Hindutva brigade Congress h...
# 12   2001-01-24  Govt extends J&K ceasefire by a month Peace hi...
# 13   2001-01-25  Big bath passes without a hitch Security bando...
# 14   2001-01-26  President against pitch for indirect polls TRA...
# 15   2001-01-27  Monster quake kills 4;000 Forces to the rescue...
# 16   2001-01-28  Death; distress; destruction...and it's not ov...
# 17   2001-01-29  More tremors forecast for the next 48 hours Th...
# 18   2001-01-30  Hrithik: Miss Indias' delight! Manoj Bajpai: F...
# 19   2001-01-31  Relief operations take back seat in Bhuj Ferna...
# 20   2001-02-01  Army cordons off Anjar; says it's a mass grave...
# 21   2001-02-02  Gujarat govt yet to get its act together Pak r...
# 22   2001-02-03  First the quake; then the flood Vajpayee; Mush...
# 23   2001-02-04  Govt to set up national disaster management pa...
# 24   2001-02-05  Official toll put at 16;435; Kutch's share 14;...
# 25   2001-02-06  PMK withdraws support; but govt safe Economic ...
# 26   2001-02-07  Tobacco firms ordered off the field Consumer c...
# 27   2001-02-08  Clear debris; start rebuilding: Centre to Guja...
# 28   2001-02-09  Copter crash brings VIP sorties under fire CAT...
# 29   2001-02-10  A new river runs through Gujarat Is there a se...
# ...         ...                                                ...
# 7050 2020-06-01  Day Knight actor bags an American film This Sa...
# 7051 2020-06-02  Trojan virus in guise of Covid-19 update Covid...
# 7052 2020-06-03  IUCN clubs Indian lions with two African lion ...
# 7053 2020-06-04  NMC plans 100-bed centre in ESI Hospital Garme...
# 7054 2020-06-05  Woman electrocuted in Deolali Camp World Envir...
# 7055 2020-06-06  Drag queens are carving a niche for themselves...
# 7056 2020-06-07  Work hard for polls: Chirag Paswan to partymen...
# 7057 2020-06-08  DK KSRTC loses Rs 86 cr during lockdown Vasco ...
# 7058 2020-06-09  New library with 49k books opens in Madikeri 6...
# 7059 2020-06-10  Wearing PPE kits can be cumbersome; but custom...
# 7060 2020-06-11  Barbers at Kashi ghats hope for biz revival Pa...
# 7061 2020-06-12  Why microbreweries can't beer it: High restart...
# 7062 2020-06-13  I have made mistakes in my career and hope not...
# 7063 2020-06-14  Weekly Horoscope; 14 to 20 June; 2020: Check p...
# 7064 2020-06-15  Horoscope Today; 15 June 2020: Check astrologi...
# 7065 2020-06-16  Pattachitra; Madhubani; kalamkari; zardosi; an...
# 7066 2020-06-17  Bus rams 22 two-wheelers; kills one Agri dept ...
# 7067 2020-06-18  Three killed in two road accidents Two detaine...
# 7068 2020-06-19  Bengaluru: Motorist who drove with cabbie on b...
# 7069 2020-06-20  City's private hospital allowed to treat coron...
# 7070 2020-06-21  Guest workers continue to throng Central rly s...
# 7071 2020-06-22  infrared thermometer popular ones to measure b...
# 7072 2020-06-23  Delayed periods? Time to accept that household...
# 7073 2020-06-24  I never thought I had a voice until today: Vid...
# 7074 2020-06-25  Truck firms look for new export markets to sel...
# 7075 2020-06-26  Containment zone residents slam high prices ch...
# 7076 2020-06-27  like me i wont let you have a toxic relationsh...
# 7077 2020-06-28  Atanu Ghosh plans to rewrite old scripts to ma...
# 7078 2020-06-29  6 hot and stylish bikini looks of Katrina Kaif...
# 7079 2020-06-30  Detective Byomkesh Bakshy! Edge of Tomorrow Fi...
#
# [7080 rows x 2 columns]

# %%
# Check for any duplicated values
ndf.isnull().sum()
# Out:
# Date    0
# News    0
# dtype: int64

# %%
len(ndf)
# Out:
# 7080

# %%
hisdf=hisdf[["Date","Open","High","Low","Close","Volume"]]
hisdf.head(-5)
# Out:
#            Date          Open          High           Low         Close  \
# 0    2019-12-17  41052.359375  41401.648438  41005.179688  41352.171875
# 1    2019-12-18  41442.750000  41614.769531  41358.468750  41558.570313
# 2    2019-12-19  41571.820313  41719.289063  41456.398438  41673.921875
# 3    2019-12-20  41746.199219  41809.960938  41636.109375  41681.539063
# 4    2019-12-23  41548.261719  41701.621094  41474.609375  41642.660156
# 5    2019-12-24  41684.511719  41702.980469  41423.070313  41461.261719
# 6    2019-12-26  41543.800781  41543.800781  41132.890625  41163.761719
# 7    2019-12-27  41297.078125  41611.269531  41264.921875  41575.140625
# 8    2019-12-30  41686.269531  41714.730469  41453.378906  41558.000000
# 9    2019-12-31  41607.488281  41607.488281  41184.730469  41253.738281
# 10   2020-01-01           NaN           NaN           NaN           NaN
# 11   2020-01-02  41340.269531  41649.289063  41328.449219  41626.640625
# 12   2020-01-03  41634.511719  41636.179688  41348.679688  41464.609375
# 13   2020-01-06  41378.339844  41378.339844  40613.960938  40676.628906
# 14   2020-01-07  40983.039063  41230.140625  40727.371094  40869.468750
# 15   2020-01-08  40574.828125  40866.359375  40476.550781  40817.738281
# 245  2020-12-09  45891.039063  46164.101563  45792.011719  46103.500000
# 246  2020-12-10  45999.421875  46043.968750  45685.871094  45959.878906
#
#       Volume
# 0    19000.0
# 1    24300.0
# 2    33300.0
# 3    33600.0
# 4     6200.0
# 5     4400.0
# 6     5600.0
# 7     6100.0
# 8     5700.0
# 9     5600.0
# 10       NaN
# 11    5300.0
# 12    8900.0
# 13    8700.0
# 14   11900.0
# 15   18200.0
# 16    7800.0
# 17   13200.0
# 18   10600.0
# 19   14100.0
# 20    6100.0
# 21    6600.0
# 22    9500.0
# 23    7500.0
# 24    8900.0
# 25    7700.0
# 26    9900.0
# 27    6600.0
# 28    7000.0
# 29    9800.0
# ..       ...
# 217  19500.0
# 218  12000.0
# 219  15400.0
# 220  21400.0
# 221  20900.0
# 222  42600.0
# 223  19000.0
# 224  24300.0
# 225  28700.0
# 226  30300.0
# 227  14500.0
# 228  24400.0
# 229      NaN
# 230  20900.0
# 231  18300.0
# 232  24100.0
# 233  17100.0
# 234  17800.0
# 235  17900.0
# 236  19100.0
# 237  14600.0
# 238  15700.0
# 239  16000.0
# 240  16000.0
# 241  30700.0
# 242  27600.0
# 243  18700.0
# 244  18200.0
# 245  20700.0
# 246  12700.0
#
# [247 rows x 6 columns]

# %%
# Check for common information of the second dataset
hisdf["Date"]= pd.to_datetime(hisdf["Date"])
hisdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 6 columns):
# Date      252 non-null datetime64[ns]
# Open      250 non-null float64
# High      250 non-null float64
# Low       250 non-null float64
# Close     250 non-null float64
# Volume    250 non-null float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 11.9 KB

# %%
hisdf.describe()
# Out:
#                Open          High           Low         Close         Volume
# count    250.000000    250.000000    250.000000    250.000000     250.000000
# mean   37804.237375  38071.182859  37422.826992  37745.454117   19134.000000
# std     4507.985769   4380.974060   4647.212947   4535.304336   16540.261333
# min    26499.810547  27462.869141  25638.900391  25981.240234       0.000000
# 25%    34369.659179  34779.932618  33975.389648  34257.097656   13125.000000
# 50%    38489.480469  38750.359375  38234.869140  38425.974610   17000.000000
# 75%    41179.222656  41376.482422  41023.923828  41135.233399   21075.000000
# max    46774.320313  46992.570313  46627.601563  46890.339844  188300.000000

# %%
# Check for duplicated values
hisdf.isnull().sum()
# Out:
# Date      0
# Open      2
# High      2
# Low       2
# Close     2
# Volume    2
# dtype: int64

# %%
len(hisdf)
# Out:
# 252

# %%
# Figure plot
plt.figure(figsize=(20,10))
hisdf['Close'].plot()
plt.ylabel('BSESN',color="white")
# Out:
# Text(0, 0.5, 'BSESN')

# %% [markdown]
# # Remove Unwanted Characters from the News

# %%
#removing unwanted characters from the News
ndf.replace("[^a-zA-Z']"," ",regex=True,inplace=True)
ndf["News"].head(5)
# Out:
# 0    win over cena satisfying but defeating underta...
# 1    Status quo will not be disturbed at Ayodhya  s...
# 2    Powerless north India gropes in the dark Think...
# 3    The string that pulled Stephen Hawking to Indi...
# 4    Light combat craft takes India into club class...
# Name: News, dtype: object

# %% [markdown]
# # Historical Analysis

# %% [markdown]
# # Plot the Moving Average

# %%
#Plotting moving average
close = hisdf['Close']

ma = close.rolling(window = 50).mean()
std = close.rolling(window = 50).std()

plt.figure(figsize=(20,10))
hisdf['Close'].plot(color='g',label='Close')
ma.plot(color = 'r',label='Rolling Mean')
std.plot(label = 'Rolling Standard Deviation')

plt.legend()

# %% [markdown]
# # Plot the Returns

# %%
#Plotting returns
returns = close / close.shift(1) - 1

plt.figure(figsize = (20,10))
returns.plot(label='Return', color = 'g')
plt.title("Returns")
# Out:
# Text(0.5, 1.0, 'Returns')

# %%
# Train test split
train = hisdf[:1219]
test = hisdf[1219:]

# %% [markdown]
# # Rolling mean and Standard Deviation

# %%
#Stationarity test
def test_stationarity(timeseries):

 #Determine the rolling statistics
 rolmean = timeseries.rolling(20).mean()
 rolstd = timeseries.rolling(20).std()

 #Plot rolling statistics:
 plt.figure(figsize = (20,10))
 plt.plot(timeseries, color = 'blue', label = 'original')
 plt.plot(rolmean, color = 'r', label = 'rolling mean')
 plt.plot(rolstd, color = 'black', label = 'rolling std')
 plt.xlabel('Date')
 plt.legend()
 plt.title('Rolling Mean and Standard Deviation',  fontsize = 30)
 plt.show(block = False)
 
 print('Results of dickey fuller test')
 result = adfuller(timeseries, autolag = 'AIC')
 labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
 for value,label in zip(result, labels):
   print(label+' : '+str(value) )
 if result[1] <= 0.05:
   print("Strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary")
 else:
   print("Weak evidence against null hypothesis, time series is non-stationary ")
test_stationarity(train['Close'])
# Out:
# Results of dickey fuller test
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-1eea8002dff7> in <module>
#      25  else:
#      26    print("Weak evidence against null hypothesis, time series is non-stationary ")
# ---> 27 test_stationarity(train['Close'])
#
# <ipython-input-23-1eea8002dff7> in test_stationarity(timeseries)
#      17
#      18  print('Results of dickey fuller test')
# ---> 19  result = adfuller(timeseries, autolag = 'AIC')
#      20  labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
#      21  for value,label in zip(result, labels):
#
# NameError: name 'adfuller' is not defined

# %%
train_log = np.log(train['Close']) 
test_log = np.log(test['Close'])

mav = train_log.rolling(24).mean() 
plt.figure(figsize = (20,10))
plt.plot(train_log) 
plt.plot(mav, color = 'red')

# %%
train_log.dropna(inplace = True)
test_log.dropna(inplace = True)

test_stationarity(train_log)

# %%
train_log_diff = train_log - mav
train_log_diff.dropna(inplace = True)

test_stationarity(train_log_diff)

# %%
#Using auto arima to make predictions using log data
from pmdarima import auto_arima

# %%
model = auto_arima(train_log, trace = True, error_action = 'ignore', suppress_warnings = True)
model.fit(train_log)
predictions = model.predict(periods = len(test))
predictions = pd.DataFrame(predictions,index = test_log.index,columns=['Prediction'])

# %%
plt.plot(train_log, label='Train')
plt.plot(test_log, label='Test')
plt.plot(predictions, label='Prediction')
plt.title('BSESN Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Actual Stock Price')

# %% [markdown]
# # Error Calculation

# %%
#Calculating error
rms = np.sqrt(mean_squared_error(test_log,predictions))
print("RMSE : ", rms)

# %% [markdown]
# # Textual Analysis

# %%
#Functions to get the subjectivity and polarity
def getSubjectivity(text):
  return TextBlob(text).sentiment.subjectivity

def getPolarity(text):
  return  TextBlob(text).sentiment.polarity

# %%
#Adding subjectivity and polarity columns
ndf['Subjectivity'] = ndf['News'].apply(getSubjectivity)
ndf['Polarity'] = ndf['News'].apply(getPolarity)
ndf

# %%
#Adding sentiment score to df_news
sia = SentimentIntensityAnalyzer()

# %%
ndf['Compound'] = [sia.polarity_scores(v)['compound'] for v in ndf['News']]
ndf['Negative'] = [sia.polarity_scores(v)['neg'] for v in ndf['News']]
ndf['Neutral'] = [sia.polarity_scores(v)['neu'] for v in ndf['News']]
ndf['Positive'] = [sia.polarity_scores(v)['pos'] for v in ndf['News']]
ndf

# %% [markdown]
# # Merge the Historical and Textual Data

# %%
df_merge = pd.merge(hisdf, ndf, how='inner', on='Date')
df_merge

# %% [markdown]
# # Create Dataset for Model Training

# %%
dfmerge1 = df_merge[['Close','Subjectivity', 'Polarity', 'Compound', 'Negative', 'Neutral', 'Positive']]
dfmerge1

# %% [markdown]
# # Normalize Data

# %%
scaler = MinMaxScaler()

df = pd.DataFrame(scaler.fit_transform(dfmerge1))
df.columns = dfmerge1.columns
df.index = dfmerge1.index
df.head()

# %%
X=df.drop('Close',axis=1)
X

# %%
Y=df['Close']
Y

# %% [markdown]
# # Split the Dataset into Train & Test Data

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state = 0)
x_train.shape

# %%
x_train[:10]

# %% [markdown]
# # RandomForestRegressor Model

# %%
rf = RandomForestRegressor()
rf.fit(x_train, y_train)
prediction=rf.predict(x_test)

# %%
print(prediction[:10])
print(y_test[:10])
print('Mean Squared error: ',mean_squared_error(prediction,y_test))

# %% [markdown]
# # DecisionTreeRegressor Model

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train, y_train)
predictions = dtr.predict(x_test)

# %%
print(predictions[:10])
print(y_test[:10])
print('Mean Squared error: ',mean_squared_error(predictions,y_test))

# %% [markdown]
# # AdaBoostRegressor Model

# %%
adb = AdaBoostRegressor()
adb.fit(x_train, y_train)

# %%
predictions = adb.predict(x_test)
print(mean_squared_error(predictions, y_test))

# %% [markdown]
# # LGBMRegressor Model

# %%
gbm = lightgbm.LGBMRegressor()
gbm.fit(x_train, y_train)

# %%
predictions = gbm.predict(x_test)
print(mean_squared_error(predictions, y_test))

# %% [markdown]
# # XGBRegressor Model

# %%
xgb = xgboost.XGBRegressor()
xgb.fit(x_train, y_train)

# %%
predictions = xgb.predict(x_test)
print(mean_squared_error(predictions, y_test))

# %% [markdown]
# # Conclusion

# %% [markdown]
# - RandomForest = 0.05257968397499098
# - DecisionTree = 0.10831900809236311
# - AdaBoost = 0.05492347045438241
# - LightGBM = 0.0583079056070462
# - XGBoost = 0.05968830860645931
# From here we can see that RandomForestRegressor shows a better performance than the others
